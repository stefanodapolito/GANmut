# %% [markdown]
# # GANmut

# %%
import sys
sys.path.append("..")
import numpy as np
from utils.notebook_utils import GANmut

# %%
#load generator and choose the type of model 'Gaussian or Linear'
G = GANmut(G_path='../learned_generators/gaus_2d/1800000-G.ckpt',model='gaussian')
# Out:
# Device: cuda

# %%
#choose the emotion coordinates x \in [-1,1], y \in [-1,1] (a map of emotion latent space is presented in the GitHub page)
G.emotion_edit(img_path='../images/Einstein.jpg', x = -0.8, y = -0.5, save = True )
# Out:
# edited image saved in ../edited_images\x_-0.80_y_-0.50Einstein.jpg

# %%
G = GANmut(G_path='../learned_generators/lin_2d/1000000-G.ckpt',model='linear')
# Out:
# Device: cuda

# %%
angle=np.pi
strength=0.3

# %%
G.emotion_edit(img_path='../images/Einstein.jpg', theta=0, rho = 0.4, save = True )
